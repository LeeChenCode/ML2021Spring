# %% [markdown]
# # **Homework 12 - Reinforcement Learning**
#
# If you have any problem, e-mail us at ntu-ml-2021spring-ta@googlegroups.com

# %% [markdown]
# ## Preliminary work
#
# First, we need to install all necessary packages.
# One of them, gym, builded by OpenAI, is a toolkit for developing Reinforcement Learning algorithm. Other packages are for visualization in colab.

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/My Drive/Colab Notebooks/') 
os.listdir()
# Out:
# Mounted at /content/drive
# ['HW1_Regression_Ding-Li',
#  '「SHARE MLSpring2021 - HW2-1.ipynb」的副本',
#  'Untitled0.ipynb',
#  'Action_List.npy',
#  'hw12_reinforcement_learning',
#  'hw12_reinforcement_learning_DQN']

# %%
# !apt update
# !apt install python-opengl xvfb -y
# !pip install gym[box2d]==0.18.3 pyvirtualdisplay tqdm numpy==1.19.5 torch==1.8.1
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:14 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,957 kB]
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,498 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,272 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,734 kB]
# Get:18 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [1,003 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,168 kB]
# Fetched 12.9 MB in 3s (3,955 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 52 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'apt autoremove' to remove them.
# Suggested packages:
#   libgle3
# The following NEW packages will be installed:
#   python-opengl xvfb
# 0 upgraded, 2 newly installed, 0 to remove and 52 not upgraded.
# Need to get 1,280 kB of archives.
# After this operation, 7,687 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-opengl all 3.1.0+dfsg-1 [496 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.10 [784 kB]
# Fetched 1,280 kB in 1s (1,177 kB/s)
# Selecting previously unselected package python-opengl.
# (Reading database ... 155203 files and directories currently installed.)
# Preparing to unpack .../python-opengl_3.1.0+dfsg-1_all.deb ...
# Unpacking python-opengl (3.1.0+dfsg-1) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.10_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.10) ...
# Setting up python-opengl (3.1.0+dfsg-1) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.10) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Collecting gym[box2d]==0.18.3
#   Downloading gym-0.18.3.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 5.2 MB/s
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.64.0)
# Collecting numpy==1.19.5
#   Downloading numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl (14.8 MB)
#      |████████████████████████████████| 14.8 MB 37.2 MB/s
# Collecting torch==1.8.1
#   Downloading torch-1.8.1-cp37-cp37m-manylinux1_x86_64.whl (804.1 MB)
#      |████████████████████████████████| 804.1 MB 2.9 kB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.8.1) (4.2.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym[box2d]==0.18.3) (1.4.1)
# Requirement already satisfied: pyglet<=1.5.15,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]==0.18.3) (1.5.0)
# Requirement already satisfied: Pillow<=8.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]==0.18.3) (7.1.2)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]==0.18.3) (1.3.0)
# Collecting box2d-py~=2.3.5
#   Downloading box2d_py-2.3.8-cp37-cp37m-manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 50.8 MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.15,>=1.4.0->gym[box2d]==0.18.3) (0.16.0)
# Building wheels for collected packages: gym
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.18.3-py3-none-any.whl size=1657531 sha256=292cc6d840d1557f4cb28a40126af7ddf90e39c014d0ae835a4dfb24bb5fd9ca
#   Stored in directory: /root/.cache/pip/wheels/1a/ec/6d/705d53925f481ab70fd48ec7728558745eeae14dfda3b49c99
# Successfully built gym
# Installing collected packages: numpy, gym, box2d-py, torch, pyvirtualdisplay
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: gym
#     Found existing installation: gym 0.17.3
#     Uninstalling gym-0.17.3:
#       Successfully uninstalled gym-0.17.3
#   Attempting uninstall: torch
#     Found existing installation: torch 1.11.0+cu113
#     Uninstalling torch-1.11.0+cu113:
#       Successfully uninstalled torch-1.11.0+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# torchvision 0.12.0+cu113 requires torch==1.11.0, but you have torch 1.8.1 which is incompatible.
# torchtext 0.12.0 requires torch==1.11.0, but you have torch 1.8.1 which is incompatible.
# torchaudio 0.11.0+cu113 requires torch==1.11.0, but you have torch 1.8.1 which is incompatible.
# tensorflow 2.8.0 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed box2d-py-2.3.8 gym-0.18.3 numpy-1.19.5 pyvirtualdisplay-3.0 torch-1.8.1

# %% [markdown]
# Next, set up virtual display，and import all necessaary packages.

# %%
# %%capture
from pyvirtualdisplay import Display
virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %matplotlib inline
import matplotlib.pyplot as plt

from IPython import display

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import Categorical
from tqdm.notebook import tqdm

# %% [markdown]
# # Warning ! Do not revise random seed !!!
# # Your submission on JudgeBoi will not reproduce your result !!!
# Make your HW result to be reproducible.

# %%
seed = 543 # Do not change this
def fix(env, seed):
  env.seed(seed)
  env.action_space.seed(seed)
  torch.manual_seed(seed)
  torch.cuda.manual_seed(seed)
  torch.cuda.manual_seed_all(seed)
  np.random.seed(seed)
  random.seed(seed)
  torch.set_deterministic(True)
  torch.backends.cudnn.benchmark = False
  torch.backends.cudnn.deterministic = True

# %% [markdown]
# Last, call gym and build an [Lunar Lander](https://gym.openai.com/envs/LunarLander-v2/) environment.

# %%
# %%capture
import gym
import random
env = gym.make('LunarLander-v2')
fix(env, seed) # fix the environment Do not revise this !!!

# %% [markdown]
# ## What Lunar Lander？
#
# “LunarLander-v2”is to simulate the situation when the craft lands on the surface of the moon.
#
# This task is to enable the craft to land "safely" at the pad between the two yellow flags.
# > Landing pad is always at coordinates (0,0).
# > Coordinates are the first two numbers in state vector.
#
# ![](https://gym.openai.com/assets/docs/aeloop-138c89d44114492fd02822303e6b4b07213010bb14ca5856d2d49d6b62d88e53.svg)
#
# "LunarLander-v2" actually includes "Agent" and "Environment".
#
# In this homework, we will utilize the function `step()` to control the action of "Agent".
#
# Then `step()` will return the observation/state and reward given by the "Environment".

# %% [markdown]
# ### Observation / State
#
# First, we can take a look at what an Observation / State looks like.

# %%
print(env.observation_space)
# Out:
# Box(-inf, inf, (8,), float32)

# %% [markdown]
# `Box(8,)`means that observation is an 8-dim vector
# ### Action
#
# Actions can be taken by looks like

# %%
print(env.action_space)
# Out:
# Discrete(4)

# %% [markdown]
# `Discrete(4)` implies that there are four kinds of actions can be taken by agent.
# - 0 implies the agent will not take any actions
# - 2 implies the agent will accelerate downward
# - 1, 3 implies the agent will accelerate left and right
#
# Next, we will try to make the agent interact with the environment.
# Before taking any actions, we recommend to call `reset()` function to reset the environment. Also, this function will return the initial state of the environment.

# %%
initial_state = env.reset()
print(initial_state)
# Out:
# [ 0.00396109  1.4083536   0.40119505 -0.11407257 -0.00458307 -0.09087662
#   0.          0.        ]

# %% [markdown]
# Then, we try to get a random action from the agent's action space.

# %%
random_action = env.action_space.sample()
print(random_action)
# Out:
# 0

# %% [markdown]
# More, we can utilize `step()` to make agent act according to the randomly-selected `random_action`.
# The `step()` function will return four values:
# - observation / state
# - reward
# - done (True/ False)
# - Other information

# %%
observation, reward, done, info = env.step(random_action)

# %%
print(observation)
print(reward)
print(done)
print(info) # nothing
# Out:
# [ 0.00792227  1.4052099   0.4006532  -0.139737   -0.00907371 -0.08982073
#   0.          0.        ]
# -0.8588900517154912
# False
# {}

# %% [markdown]
# ### Reward
#
#
# > Landing pad is always at coordinates (0,0). Coordinates are the first two numbers in state vector. Reward for moving from the top of the screen to landing pad and zero speed is about 100..140 points. If lander moves away from landing pad it loses reward back. Episode finishes if the lander crashes or comes to rest, receiving additional -100 or +100 points. Each leg ground contact is +10. Firing main engine is -0.3 points each frame. Solved is 200 points.

# %%
print(reward)
# Out:
# -0.8588900517154912

# %% [markdown]
# ### Random Agent
# In the end, before we start training, we can see whether a random agent can successfully land the moon or not.

# %%
'''
env.reset()

img = plt.imshow(env.render(mode='rgb_array'))

done = False
while not done:
    action = env.action_space.sample()
    observation, reward, done, _ = env.step(action)

    img.set_data(env.render(mode='rgb_array'))
    display.display(plt.gcf())
    display.clear_output(wait=True)
'''
# Out:
# "\nenv.reset()\n\nimg = plt.imshow(env.render(mode='rgb_array'))\n\ndone = False\nwhile not done:\n    action = env.action_space.sample()\n    observation, reward, done, _ = env.step(action)\n\n    img.set_data(env.render(mode='rgb_array'))\n    display.display(plt.gcf())\n    display.clear_output(wait=True)\n"

# %% [markdown]
# ## DQN
# Now, we can build a DQN network. The network will return one of action in the action space.

# %%
class DQN(nn.Module):
    """Actor (Policy) Model."""

    def __init__(self, state_size=8, action_size=4, fc1_units=64, fc2_units=64):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
            fc1_units (int): Number of nodes in first hidden layer
            fc2_units (int): Number of nodes in second hidden layer
        """
        super(DQN, self).__init__() # inherit
        self.fc1 = nn.Linear(state_size, fc1_units)
        self.fc2 = nn.Linear(fc1_units, fc2_units)
        self.fc3 = nn.Linear(fc2_units, action_size)

    def forward(self, state):
        """Build a network that maps state -> action values(reward)."""
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

# %% [markdown]
# Then, we need to build a simple agent. The agent will acts according to the output of the policy network above. There are a few things can be done by agent:
# - `learn()`：update the policy network from log probabilities and rewards.
# - `sample()`：After receiving observation from the environment, utilize policy network to tell which action to take. The return values of this function includes action and log probabilities.

# %%
from collections import namedtuple

class ReplayMemory:
    """Fixed-size buffer to store experience tuples."""
    def __init__(self, CAPACITY):
        self.capacity = CAPACITY  
        self.memory = []  
        self.index = 0  
        self.transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))
        
    def push(self, state, action, state_next, reward):
        """Push a new experience to memory."""
        if len(self.memory) < self.capacity: # if still has capacity, initialize memory[index] to None
            self.memory.append(None)

        self.memory[self.index] = self.transition(state, action, state_next, reward)

        self.index = (self.index + 1) % self.capacity  # circular index

    def sample(self, batch_size):
        """Randomly sample a batch of experiences from memory."""
        return random.sample(self.memory, batch_size)

    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %%
class DQNAgent():
    """Interacts with and learns from the environment."""
    def __init__(self, num_states, num_actions):
        """Initialize an Agent object."""
        
        self.num_states = num_states
        self.num_actions = num_actions
        
        # Replay memory
        self.memory_capacity = 10000
        self.memory = ReplayMemory(self.memory_capacity)
        
        # Q-Network
        self.main_q_network = DQN() 
        self.target_q_network = DQN()
        
        # optimizer
        self.optimizer = optim.RMSprop(self.main_q_network.parameters(), lr=1e-4)
    
    def update_q_function(self):
        '''update q function'''
        
        # no enough samples, just return
        if len(self.memory) < BATCH_SIZE:
            return
        # If enough samples are available in memory, get random subset and learn
        self.batch, self.state_batch, self.action_batch, self.reward_batch, self.non_final_next_states = self.make_minibatch()
        
        self.expected_state_action_values = self.get_expected_state_action_values()

        self.update_main_q_network()

    def make_minibatch(self):
        '''Creating a mini-batch'''

        transitions = self.memory.sample(BATCH_SIZE)

        Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))
        batch = Transition(*zip(*transitions))


        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state
                                           if s is not None])

        return batch, state_batch, action_batch, reward_batch, non_final_next_states

    def get_expected_state_action_values(self):
        '''calculate Q（St,at）'''

        self.main_q_network.eval()
        self.target_q_network.eval()

        self.state_action_values = self.main_q_network(
            self.state_batch).gather(1, self.action_batch)

        non_final_mask = torch.BoolTensor(tuple(map(lambda s: s is not None,
                                                    self.batch.next_state)))
        # set all state to 0
        next_state_values = torch.zeros(BATCH_SIZE)

        next_state_values[non_final_mask] = self.target_q_network(
            self.non_final_next_states).max(1)[0].detach()
        # DQN formula
        expected_state_action_values = self.reward_batch + GAMMA * next_state_values
        
        return expected_state_action_values 
        
    def get_action(self, state, episode, test=False):
        """Returns actions for given state as per current policy."""
        if test:
            self.main_q_network.eval()
            with torch.no_grad():
                # t.max(1) will return largest column value of each row.
                # second column on max result is index of where max element was
                # found, so we pick action with the larger expected reward.
                action = self.main_q_network(torch.from_numpy(state).unsqueeze(0)).max(1)[1].view(1, 1)
            return action.item()
        
        global steps_done
        # Epsilon-greedy policy
        # https://www.baeldung.com/cs/epsilon-greedy-q-learning 
        # pick action by
        # 1:max reward if epsilon < np.random.uniform
        # 2:otherwise, pick action randomly

        #epsilon = episode
        #epsilon = 0.5 * (1 / (episode + 1))
        epsilon = EPS_END + (EPS_START - EPS_END) * \
                np.exp(-1. * steps_done / EPS_DECAY)
        #print('epsilon', epsilon)
        
        steps_done += 1
        
        if epsilon <= np.random.uniform(0, 1):
            #print('use max')
            self.main_q_network.eval()
            with torch.no_grad():
                # t.max(1) will return largest column value of each row.
                # second column on max result is index of where max element was
                # found, so we pick action with the larger expected reward.
                action = self.main_q_network(state).max(1)[1].view(1, 1)
        else:
            #print('random')
            action = torch.LongTensor(
                [[random.randrange(self.num_actions)]])  
            
        return action

    def update_main_q_network(self):
        
        '''update main q net'''

        # set train mode
        self.main_q_network.train()
        # Hurberloss function
        # expected_state_action_values (minbatch,)->(minbatchx1)

        #https://pytorch.org/docs/stable/generated/torch.nn.SmoothL1Loss.html#torch.nn.SmoothL1Loss 
        # temporal difference error
        loss = F.smooth_l1_loss(self.state_action_values,
                                self.expected_state_action_values.unsqueeze(1))

        # update
        self.optimizer.zero_grad()  # reset gradient
        loss.backward()  # backpropagation
        for param in self.main_q_network.parameters():
            param.grad.data.clamp_(-1, 1)
        self.optimizer.step()  # update network


    def memorize(self, state, action, state_next, reward):
        '''save state, action, state_next, reward into replay memory'''
        self.memory.push(state, action, state_next, reward)

    def update_target_q_function(self):
        
        '''synchronize Target Q-Network as Main Q-Network'''
        self.target_q_network.load_state_dict(self.main_q_network.state_dict())

# %% [markdown]
# Lastly, build a network and agent to start training.

# %%
network = DQN()
agent = DQNAgent(env.observation_space.shape[0], env.action_space.n)

# %% [markdown]
# ## Trainin Agent
#
# Now let's start to train our agent.
# Through taking all the interactions between agent and environment as training data, the policy network can learn from all these attempts,

# %%
EPISODE_PER_BATCH = 5  # update agent every "EPISODE_PER_BATCH" episodes
NUM_BATCH = 600        # total update number
BATCH_SIZE = 32
GAMMA = 0.99           # weight decay
EPS_START = 0.9        # for epsilon 
EPS_END = 0.05         # for epsilon 
EPS_DECAY = 200        # for epsilon 

best_score = 0
best_batch = 0


# ensure network is in training mode before training start
agent.main_q_network.train()
agent.target_q_network.train()
steps_done = 0

avg_total_rewards, avg_final_rewards = [], []

prg_bar = tqdm(range(NUM_BATCH))
for batch in prg_bar:
    print(f"Current batch : ", batch)  
    rewards = []
    total_rewards, final_rewards = [], []

    # collect training data
    for episode in range(EPISODE_PER_BATCH):
        
        observation = env.reset() 
        state = observation  # use observation as state s
        state = torch.from_numpy(state).type(
                torch.FloatTensor)  # 
        state = torch.unsqueeze(state, 0)  # size from 4 to 1x4
        total_reward, total_step = 0, 0

        while True:

            action = agent.get_action(state, batch)  
            # get action a_t
            # perform action a_t, then calculate s_{t+1} and get done flag 
            # get info base on action result
            observation_next, reward, done, _ = env.step(action.item())  # no info flag，so set it as _

            total_reward += reward
            total_step += 1
            rewards.append(reward) 

            if done:
                state_next = None  # no next state so store it as None

            else:
                state_next = observation_next  
                state_next = torch.from_numpy(state_next).type(
                        torch.FloatTensor)  
                state_next = torch.unsqueeze(state_next, 0)  
                
            # store this action result into memory 
            agent.memorize(state, action, state_next, torch.FloatTensor([reward]))
            
            # update q function with experience replay
            agent.update_q_function()
            
            # update observation state
            state = state_next
            
            # 
            if done:
                final_rewards.append(reward)
                total_rewards.append(total_reward)
                break
                

    #print(f"rewards looks like ", np.shape(rewards))      
    avg_total_reward = sum(total_rewards) / len(total_rewards)
    avg_final_reward = sum(final_rewards) / len(final_rewards)
    avg_total_rewards.append(avg_total_reward)
    avg_final_rewards.append(avg_final_reward)
    prg_bar.set_description(f"Total: {avg_total_reward: 4.1f}, Final: {avg_final_reward: 4.1f}")

    # rewards = np.concatenate(rewards, axis=0)
    #rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-9)  

    # update target q function 
    agent.update_target_q_function()
    print("torch.from_numpy(rewards) looks like ", torch.from_numpy(np.array(rewards)).size())


    ### testing

    fix(env, seed)
    agent.main_q_network.eval()  
    NUM_OF_TEST = 5 # Do not revise it !!!!!
    test_total_reward = []
    action_list = []
    for i in range(NUM_OF_TEST):
        actions = []
        state = env.reset()

        #img = plt.imshow(env.render(mode='rgb_array'))

        total_reward = 0

        done = False
        while not done:
            action = agent.get_action(state, episode=i, test=True)
            actions.append(action)
            state, reward, done, _ = env.step(action)

            total_reward += reward

            #img.set_data(env.render(mode='rgb_array'))
            #display.display(plt.gcf())
            #display.clear_output(wait=True)
        print(total_reward)
        test_total_reward.append(total_reward)

        action_list.append(actions) 
        print("length of actions is ", len(actions))
    print(f"Your final reward is : %.2f"%np.mean(test_total_reward))
    if np.mean(test_total_reward) > 250:
        distribution = {}
        for actions in action_list:
            for action in actions:
                if action not in distribution.keys():
                    distribution[action] = 1
                else:
                    distribution[action] += 1
        PATH = "Action_List_test" + str(batch) + ".npy" #
        np.save(PATH ,np.array(action_list)) 
        if np.mean(test_total_reward) > best_score:
            best_score = np.mean(test_total_reward)
            best_batch = batch
            print('Improve to score %.2f at batch %d'% (best_score, best_batch ))
# Out:
#   0%|          | 0/600 [00:00<?, ?it/s]
# torch.from_numpy(rewards) looks like  torch.Size([527])
# -579.853934930769
# length of actions is  77
# -405.1058660065534
# length of actions is  87
# -646.0210455104375
# length of actions is  73
# /usr/local/lib/python3.7/dist-packages/torch/__init__.py:422: UserWarning: torch.set_deterministic is deprecated and will be removed in a future release. Please use torch.use_deterministic_algorithms instead
#   "torch.set_deterministic is deprecated and will be removed in a future "
# -321.8099531722073
# length of actions is  77
# -638.1286873878623
# length of actions is  77
# Your final reward is : -518.18
# torch.from_numpy(rewards) looks like  torch.Size([419])
# -152.00620379883682
# length of actions is  89
# -280.42266942670574
# length of actions is  57
# -5.8364090921424605
# length of actions is  78
# -80.77579000747384
# length of actions is  96
# -199.49814279603552
# length of actions is  102
# Your final reward is : -143.71
# torch.from_numpy(rewards) looks like  torch.Size([890])
# -252.06893260114913
# length of actions is  134
# -398.23468398087044
# length of actions is  110
# -336.5705628968486
# length of actions is  362
# -230.67612560545552
# length of actions is  112
# -194.63639919973127
# length of actions is  121
# Your final reward is : -282.44
# torch.from_numpy(rewards) looks like  torch.Size([1433])
# -191.36458888809116
# length of actions is  1000
# -176.55997779330187
# length of actions is  1000
# -189.20706465267614
# length of actions is  1000
# -194.66705193496142
# length of actions is  1000
# -229.39313143772407
# length of actions is  1000
# Your final reward is : -196.24
# torch.from_numpy(rewards) looks like  torch.Size([2979])
# -331.5001165739168
# length of actions is  186
# -134.1059007055402
# length of actions is  207
# -288.2839854055723
# length of actions is  651
# -30.866711906900292
# length of actions is  195
# -182.36087663103177
# length of actions is  229
# Your final reward is : -193.42
# torch.from_numpy(rewards) looks like  torch.Size([1270])
# -159.7632792506521
# length of actions is  182
# -270.86585294092924
# length of actions is  473
# -107.54960947641021
# length of actions is  318
# -248.74268211569742
# length of actions is  262
# -190.9874411497365
# length of actions is  220
# Your final reward is : -195.58
# torch.from_numpy(rewards) looks like  torch.Size([2872])
# -192.76953630904404
# length of actions is  571
# -260.70247816612783
# length of actions is  536
# -94.93257040655077
# length of actions is  382
# -96.16886337316039
# length of actions is  655
# -250.85159105657
# length of actions is  519
# Your final reward is : -179.09
# torch.from_numpy(rewards) looks like  torch.Size([3980])
# -305.8631705241732
# length of actions is  711
# 149.2775351411816
# length of actions is  687
# 2.717220568223886
# length of actions is  1000
# -45.22800688990113
# length of actions is  1000
# -117.26886844000386
# length of actions is  1000
# Your final reward is : -63.27
# torch.from_numpy(rewards) looks like  torch.Size([2724])
# -50.253723084871865
# length of actions is  520
# 138.2612676174657
# length of actions is  769
# 113.35231490719178
# length of actions is  584
# 211.28877745212048
# length of actions is  415
# -186.79783634368226
# length of actions is  297
# Your final reward is : 45.17
# torch.from_numpy(rewards) looks like  torch.Size([2308])
# -259.6262285628535
# length of actions is  467
# -195.17268866843494
# length of actions is  300
# -53.69230509502708
# length of actions is  400
# 152.40455055382802
# length of actions is  735
# -200.99586412912402
# length of actions is  292
# Your final reward is : -111.42
# torch.from_numpy(rewards) looks like  torch.Size([1749])
# -75.79413518660132
# length of actions is  529
# 192.69005606925356
# length of actions is  537
# -187.86070701994177
# length of actions is  1000
# 20.77814834007748
# length of actions is  356
# -193.38261310639612
# length of actions is  1000
# Your final reward is : -48.71
# torch.from_numpy(rewards) looks like  torch.Size([2191])
# 160.19370771399778
# length of actions is  714
# -153.2623954620961
# length of actions is  1000
# -237.1703640573319
# length of actions is  462
# -166.51489728878204
# length of actions is  1000
# -255.3075672176785
# length of actions is  980
# Your final reward is : -130.41
# torch.from_numpy(rewards) looks like  torch.Size([2623])
# -136.89147015339253
# length of actions is  1000
# -65.47290990274686
# length of actions is  1000
# 193.0992101563174
# length of actions is  543
# -28.28208596145322
# length of actions is  595
# -152.41436814678735
# length of actions is  1000
# Your final reward is : -37.99
# torch.from_numpy(rewards) looks like  torch.Size([4369])
# -140.5550179808092
# length of actions is  1000
# -92.84778098748004
# length of actions is  1000
# -104.30673977876826
# length of actions is  1000
# -129.95618369950452
# length of actions is  1000
# -162.2146067626062
# length of actions is  1000
# Your final reward is : -125.98
# torch.from_numpy(rewards) looks like  torch.Size([4107])
# -158.95620029237563
# length of actions is  1000
# -93.59275251725856
# length of actions is  1000
# -101.5259136818275
# length of actions is  1000
# -148.96709261469573
# length of actions is  1000
# -174.40378169597372
# length of actions is  1000
# Your final reward is : -135.49
# torch.from_numpy(rewards) looks like  torch.Size([4328])
# -145.72667503485917
# length of actions is  1000
# -76.97949609592803
# length of actions is  1000
# -85.42649500375883
# length of actions is  1000
# -137.448055922601
# length of actions is  1000
# -176.58489382228686
# length of actions is  1000
# Your final reward is : -124.43
# torch.from_numpy(rewards) looks like  torch.Size([4677])
# -129.18656834543705
# length of actions is  1000
# -78.77291677418609
# length of actions is  1000
# -86.92058642962115
# length of actions is  1000
# -121.67737422570981
# length of actions is  1000
# -152.7732100476697
# length of actions is  1000
# Your final reward is : -113.87
# torch.from_numpy(rewards) looks like  torch.Size([5000])
# -136.1550454255276
# length of actions is  1000
# -72.91052721215546
# length of actions is  1000
# -80.02001352949411
# length of actions is  1000
# -128.92477732330943
# length of actions is  1000
# -163.76845601217138
# length of actions is  1000
# Your final reward is : -116.36
# torch.from_numpy(rewards) looks like  torch.Size([5000])
# -129.4076664234975
# length of actions is  1000
# -70.84545401647976
# length of actions is  1000
# -75.17349609731733
# length of actions is  1000
# -128.76150125839743
# length of actions is  1000
# -166.39149653928996
# length of actions is  1000
# Your final reward is : -114.12
# torch.from_numpy(rewards) looks like  torch.Size([4859])
# -115.25327356883874
# length of actions is  1000
# -9.880664707525433
# length of actions is  1000
# 124.43747022860636
# length of actions is  999
# -125.86037725594768
# length of actions is  1000
# 10.101650054383706
# length of actions is  1000
# Your final reward is : -23.29
# torch.from_numpy(rewards) looks like  torch.Size([5000])
# -93.41564417063303
# length of actions is  1000
# -27.395124153240697
# length of actions is  1000
# -11.511657752848974
# length of actions is  1000
# -99.0353307540165
# length of actions is  1000
# -111.91593008645293
# length of actions is  1000
# Your final reward is : -68.65
# torch.from_numpy(rewards) looks like  torch.Size([4868])
# -88.83297331961009
# length of actions is  1000
# 80.843244439952
# length of actions is  905
# -79.07936765233704
# length of actions is  1000
# -79.35017196386734
# length of actions is  1000
# -62.72909031188235
# length of actions is  1000
# Your final reward is : -45.83
# torch.from_numpy(rewards) looks like  torch.Size([3956])
# 109.17002901612592
# length of actions is  589
# 147.45305954442097
# length of actions is  772
# -69.75707451424063
# length of actions is  1000
# -104.40822960645124
# length of actions is  601
# -30.863450035870375
# length of actions is  1000
# Your final reward is : 10.32
# torch.from_numpy(rewards) looks like  torch.Size([3521])
# 129.56732121862484
# length of actions is  470
# 13.543895549086743
# length of actions is  1000
# 188.10843176775194
# length of actions is  946
# 76.941448370519
# length of actions is  923
# -70.95441665745572
# length of actions is  1000
# Your final reward is : 67.44
# torch.from_numpy(rewards) looks like  torch.Size([2139])
# -55.78970147724852
# length of actions is  205
# 138.15070812182
# length of actions is  449
# 218.84548060555443
# length of actions is  528
# -22.85830058865274
# length of actions is  124
# 133.8955523073601
# length of actions is  642
# Your final reward is : 82.45
# torch.from_numpy(rewards) looks like  torch.Size([4882])
# 168.88890718014812
# length of actions is  384
# 123.23535344870281
# length of actions is  466
# -29.30380570004276
# length of actions is  205
# -40.148851827857094
# length of actions is  1000
# 27.172911273997755
# length of actions is  985
# Your final reward is : 49.97
# torch.from_numpy(rewards) looks like  torch.Size([3547])
# 160.1408213957938
# length of actions is  437
# 62.50935740555041
# length of actions is  1000
# 142.81958382225147
# length of actions is  529
# 205.13178126893254
# length of actions is  527
# -0.18424376919577412
# length of actions is  1000
# Your final reward is : 114.08
# torch.from_numpy(rewards) looks like  torch.Size([3098])
# 180.05896171928487
# length of actions is  316
# 128.6780080945864
# length of actions is  562
# 176.98737139330052
# length of actions is  384
# 102.1235356844184
# length of actions is  821
# -29.079015923835385
# length of actions is  1000
# Your final reward is : 111.75
# torch.from_numpy(rewards) looks like  torch.Size([2777])
# 181.9846539342152
# length of actions is  417
# 169.5753703321309
# length of actions is  298
# 220.17957789246051
# length of actions is  537
# 125.81682931021008
# length of actions is  747
# -85.24850613998629
# length of actions is  143
# Your final reward is : 122.46
# torch.from_numpy(rewards) looks like  torch.Size([2207])
# 175.9509646596729
# length of actions is  501
# -0.33339076563031667
# length of actions is  1000
# 145.19590928975788
# length of actions is  438
# 88.57577276619034
# length of actions is  997
# 168.98367799335546
# length of actions is  854
# Your final reward is : 115.67
# torch.from_numpy(rewards) looks like  torch.Size([2082])
# 63.24225623454397
# length of actions is  1000
# 144.87994692960265
# length of actions is  1000
# 174.59940199884642
# length of actions is  618
# 180.13372332551273
# length of actions is  713
# -85.95928224520748
# length of actions is  224
# Your final reward is : 95.38
# torch.from_numpy(rewards) looks like  torch.Size([2493])
# 64.46000203044278
# length of actions is  1000
# 209.14347727094543
# length of actions is  546
# 78.78968004323983
# length of actions is  836
# 198.02856265661302
# length of actions is  436
# 134.02050786063683
# length of actions is  628
# Your final reward is : 136.89
# torch.from_numpy(rewards) looks like  torch.Size([2528])
# 159.77919458907576
# length of actions is  263
# 144.12186931882678
# length of actions is  556
# 127.81530428482148
# length of actions is  664
# -76.71443650819609
# length of actions is  390
# -78.43194997654184
# length of actions is  139
# Your final reward is : 55.31
# torch.from_numpy(rewards) looks like  torch.Size([1497])
# 166.6369572816655
# length of actions is  246
# -43.72329144319771
# length of actions is  402
# 38.47217992561417
# length of actions is  1000
# 200.15418515844755
# length of actions is  357
# -8.203745397244361
# length of actions is  164
# Your final reward is : 70.67
# torch.from_numpy(rewards) looks like  torch.Size([2080])
# 164.61828836328618
# length of actions is  276
# 179.31164705495843
# length of actions is  430
# 164.4745319028313
# length of actions is  726
# -8.797160562356709
# length of actions is  204
# -42.073230317604654
# length of actions is  421
# Your final reward is : 91.51
# torch.from_numpy(rewards) looks like  torch.Size([2197])
# 177.81935523086645
# length of actions is  623
# -70.42132940706186
# length of actions is  115
# 218.13134903615997
# length of actions is  480
# 170.3668810100139
# length of actions is  424
# 189.95223274192858
# length of actions is  382
# Your final reward is : 137.17
# torch.from_numpy(rewards) looks like  torch.Size([1971])
# 169.78882802033087
# length of actions is  307
# 240.1536332461214
# length of actions is  208
# 187.32825065590782
# length of actions is  339
# -46.94570226486154
# length of actions is  346
# 189.10318151544925
# length of actions is  320
# Your final reward is : 147.89
# torch.from_numpy(rewards) looks like  torch.Size([2417])
# 158.55264708428155
# length of actions is  312
# -79.55610523370542
# length of actions is  177
# -67.82403154450036
# length of actions is  248
# -58.488636986367624
# length of actions is  139
# 176.34771193297144
# length of actions is  415
# Your final reward is : 25.81
# torch.from_numpy(rewards) looks like  torch.Size([2099])
# 179.8910801240935
# length of actions is  327
# 164.4011996159171
# length of actions is  451
# -94.05163298721006
# length of actions is  285
# 149.9482808730732
# length of actions is  532
# 229.68427371632117
# length of actions is  233
# Your final reward is : 125.97
# torch.from_numpy(rewards) looks like  torch.Size([2321])
# 154.39619201337294
# length of actions is  344
# -37.46170354092985
# length of actions is  144
# -26.579805208864286
# length of actions is  111
# -38.410111943359695
# length of actions is  124
# -35.18520221891009
# length of actions is  150
# Your final reward is : 3.35
# torch.from_numpy(rewards) looks like  torch.Size([1318])
# 168.6076584096495
# length of actions is  320
# 209.17321266700603
# length of actions is  315
# -69.58260748014638
# length of actions is  292
# 188.49145495895172
# length of actions is  222
# -214.10104892344373
# length of actions is  287
# Your final reward is : 56.52
# torch.from_numpy(rewards) looks like  torch.Size([1348])
# 162.0807611895496
# length of actions is  342
# -83.86753387816651
# length of actions is  139
# 148.3247290944996
# length of actions is  528
# -26.69327360334519
# length of actions is  179
# -31.848288829328453
# length of actions is  195
# Your final reward is : 33.60
# torch.from_numpy(rewards) looks like  torch.Size([2504])
# 166.798351040561
# length of actions is  429
# -114.13617050442211
# length of actions is  135
# -28.581679881140786
# length of actions is  101
# -17.830601167657477
# length of actions is  119
# 153.712925696151
# length of actions is  603
# Your final reward is : 31.99
# torch.from_numpy(rewards) looks like  torch.Size([1366])
# 148.9468781803902
# length of actions is  326
# -50.3665801305724
# length of actions is  1000
# 164.56429216812992
# length of actions is  563
# -45.85207378880802
# length of actions is  136
# -27.428706859813843
# length of actions is  110
# Your final reward is : 37.97
# torch.from_numpy(rewards) looks like  torch.Size([2254])
# -2.507954810497869
# length of actions is  1000
# -43.16908873682121
# length of actions is  102
# 172.44796039771887
# length of actions is  553
# 164.2933665773714
# length of actions is  464
# 193.25059210988184
# length of actions is  233
# Your final reward is : 96.86
# torch.from_numpy(rewards) looks like  torch.Size([1180])
# 131.9741883000032
# length of actions is  450
# -28.28216737956714
# length of actions is  87
# 126.45175951677321
# length of actions is  509
# 168.51339003148735
# length of actions is  500
# 170.0672282897095
# length of actions is  525
# Your final reward is : 113.74
# torch.from_numpy(rewards) looks like  torch.Size([1623])
# 73.08545257166959
# length of actions is  838
# -35.118345404384954
# length of actions is  152
# -38.49196970499689
# length of actions is  132
# -56.00947527793983
# length of actions is  123
# 120.43683586889782
# length of actions is  801
# Your final reward is : 12.78
# torch.from_numpy(rewards) looks like  torch.Size([1976])
# 80.42920715125362
# length of actions is  902
# 194.3275774634322
# length of actions is  369
# -116.90431057366713
# length of actions is  110
# 100.54748407096113
# length of actions is  825
# 73.30552837869833
# length of actions is  796
# Your final reward is : 66.34
# torch.from_numpy(rewards) looks like  torch.Size([2321])
# 143.99785512280124
# length of actions is  445
# 228.20776173993127
# length of actions is  386
# -67.55665999448672
# length of actions is  121
# 152.57793511757836
# length of actions is  624
# 39.45276771855031
# length of actions is  1000
# Your final reward is : 99.34
# torch.from_numpy(rewards) looks like  torch.Size([2493])
# 133.42009218873818
# length of actions is  621
# 17.167115419855712
# length of actions is  1000
# 144.06055800180985
# length of actions is  612
# 93.76439406693342
# length of actions is  712
# -17.403202590990958
# length of actions is  135
# Your final reward is : 74.20
# torch.from_numpy(rewards) looks like  torch.Size([1819])
# 127.50330450387345
# length of actions is  679
# -33.8559416847295
# length of actions is  85
# 135.0716604604069
# length of actions is  630
# -49.90434423686145
# length of actions is  120
# 182.45035027446045
# length of actions is  258
# Your final reward is : 72.25
# torch.from_numpy(rewards) looks like  torch.Size([3177])
# 123.8982580253383
# length of actions is  581
# 150.6844621489257
# length of actions is  413
# 120.90891562654551
# length of actions is  979
# -74.60977675438185
# length of actions is  1000
# -48.127259833085674
# length of actions is  104
# Your final reward is : 54.55
# torch.from_numpy(rewards) looks like  torch.Size([2977])
# 102.57195057196392
# length of actions is  851
# 143.84823167619953
# length of actions is  829
# 174.00914218485374
# length of actions is  584
# -40.65590241822663
# length of actions is  142
# 99.81898086240328
# length of actions is  815
# Your final reward is : 95.92
# torch.from_numpy(rewards) looks like  torch.Size([2350])
# 101.40714265422173
# length of actions is  704
# -55.89725865030021
# length of actions is  108
# 165.24304545983134
# length of actions is  915
# -84.7687148141173
# length of actions is  142
# -42.25182087027976
# length of actions is  104
# Your final reward is : 16.75
# torch.from_numpy(rewards) looks like  torch.Size([3001])
# 57.39252751316784
# length of actions is  1000
# -58.40885258151378
# length of actions is  86
# -81.27448179287161
# length of actions is  129
# -57.98744127625395
# length of actions is  107
# 33.18820909633215
# length of actions is  1000
# Your final reward is : -21.42
# torch.from_numpy(rewards) looks like  torch.Size([4356])
# 101.44051633988
# length of actions is  778
# -40.708710736317016
# length of actions is  92
# -25.926761089299248
# length of actions is  91
# -25.785683461930986
# length of actions is  137
# -36.491062922092965
# length of actions is  117
# Your final reward is : -5.49
# torch.from_numpy(rewards) looks like  torch.Size([2334])
# 110.67438571021245
# length of actions is  708
# -34.768415361170725
# length of actions is  1000
# 146.8608916390587
# length of actions is  281
# 167.28278582572867
# length of actions is  409
# -73.80447439870089
# length of actions is  1000
# Your final reward is : 63.25
# torch.from_numpy(rewards) looks like  torch.Size([2863])
# 80.22336525986026
# length of actions is  921
# -27.174357339791793
# length of actions is  1000
# -24.58097935813494
# length of actions is  156
# 173.9564969220899
# length of actions is  504
# 166.48537198103057
# length of actions is  320
# Your final reward is : 73.78
# torch.from_numpy(rewards) looks like  torch.Size([2448])
# 99.22752181962902
# length of actions is  694
# 205.968917063501
# length of actions is  409
# -17.813146131081396
# length of actions is  98
# 104.01845934197101
# length of actions is  670
# -22.3789340468807
# length of actions is  1000
# Your final reward is : 73.80
# torch.from_numpy(rewards) looks like  torch.Size([3402])
# 70.56062624147283
# length of actions is  897
# 129.53175796981753
# length of actions is  834
# -58.43143762009889
# length of actions is  122
# -61.42120410685905
# length of actions is  109
# 172.2346994164864
# length of actions is  671
# Your final reward is : 50.49
# torch.from_numpy(rewards) looks like  torch.Size([3667])
# -53.20921067010332
# length of actions is  1000
# -41.38948359327024
# length of actions is  94
# 192.28162053892146
# length of actions is  235
# 114.75993948688875
# length of actions is  1000
# -57.01662206477488
# length of actions is  1000
# Your final reward is : 31.09
# torch.from_numpy(rewards) looks like  torch.Size([1091])
# -69.96555669203178
# length of actions is  639
# 20.78587813105264
# length of actions is  149
# 195.71036467110522
# length of actions is  208
# 166.52366355362392
# length of actions is  611
# -43.53518223481218
# length of actions is  125
# Your final reward is : 53.90
# torch.from_numpy(rewards) looks like  torch.Size([3298])
# 165.2654410124738
# length of actions is  600
# 235.6974560309521
# length of actions is  346
# 233.49285802123075
# length of actions is  389
# 223.2138966554269
# length of actions is  487
# 206.38159602506548
# length of actions is  474
# Your final reward is : 212.81
# torch.from_numpy(rewards) looks like  torch.Size([2642])
# -55.143400700387616
# length of actions is  525
# 178.1792756309826
# length of actions is  380
# 93.0276428689942
# length of actions is  858
# 201.30980322723886
# length of actions is  212
# 92.4088941612688
# length of actions is  1000
# Your final reward is : 101.96
# torch.from_numpy(rewards) looks like  torch.Size([2422])
# 76.45586521270928
# length of actions is  1000
# -36.792401337769206
# length of actions is  107
# 226.91785117762134
# length of actions is  344
# -19.517299711279264
# length of actions is  132
# -55.19460427674382
# length of actions is  185
# Your final reward is : 38.37
# torch.from_numpy(rewards) looks like  torch.Size([2863])
# 61.40571102372107
# length of actions is  1000
# -30.343864122532864
# length of actions is  112
# 90.57671115726765
# length of actions is  1000
# 174.33758647321287
# length of actions is  490
# 189.63709202123215
# length of actions is  485
# Your final reward is : 97.12
# torch.from_numpy(rewards) looks like  torch.Size([2162])
# 89.06884965555743
# length of actions is  1000
# -43.47358037627487
# length of actions is  104
# 172.4863370361025
# length of actions is  568
# 212.14179746524988
# length of actions is  423
# 192.79987585068986
# length of actions is  661
# Your final reward is : 124.60
# torch.from_numpy(rewards) looks like  torch.Size([2657])
# 73.7295863723516
# length of actions is  1000
# 192.59157988527312
# length of actions is  246
# 94.89496634844586
# length of actions is  1000
# 129.79773232241243
# length of actions is  710
# 115.93695916794134
# length of actions is  1000
# Your final reward is : 121.39
# torch.from_numpy(rewards) looks like  torch.Size([1542])
# 88.93720128796669
# length of actions is  1000
# 201.61278282486722
# length of actions is  168
# 150.57477741877452
# length of actions is  483
# 185.04503270184074
# length of actions is  221
# 76.28636975452753
# length of actions is  1000
# Your final reward is : 140.49
# torch.from_numpy(rewards) looks like  torch.Size([2149])
# 2.208315587291324
# length of actions is  264
# 175.69039279207908
# length of actions is  459
# 210.8060333749006
# length of actions is  381
# 218.44464303682076
# length of actions is  427
# 207.931812960761
# length of actions is  526
# Your final reward is : 163.02
# torch.from_numpy(rewards) looks like  torch.Size([2639])
# 93.07606181788866
# length of actions is  1000
# 200.8444065107121
# length of actions is  161
# 107.27690028110783
# length of actions is  1000
# 170.9844296192727
# length of actions is  526
# 195.9457324828747
# length of actions is  176
# Your final reward is : 153.63
# torch.from_numpy(rewards) looks like  torch.Size([2221])
# 94.62507979562147
# length of actions is  1000
# 186.72794916603576
# length of actions is  300
# 123.83877433957433
# length of actions is  1000
# 83.386846876238
# length of actions is  1000
# 93.94861513842449
# length of actions is  1000
# Your final reward is : 116.51
# torch.from_numpy(rewards) looks like  torch.Size([2919])
# 113.1072662823382
# length of actions is  1000
# 188.00716170787825
# length of actions is  314
# 201.96800857539043
# length of actions is  276
# 202.00338196576618
# length of actions is  336
# 191.27282800333768
# length of actions is  356
# Your final reward is : 179.27
# torch.from_numpy(rewards) looks like  torch.Size([2513])
# 217.253552833065
# length of actions is  308
# -11.553353684338163
# length of actions is  258
# 195.41348156484986
# length of actions is  446
# 204.47180725858595
# length of actions is  336
# 211.37028075152512
# length of actions is  343
# Your final reward is : 163.39
# torch.from_numpy(rewards) looks like  torch.Size([2602])
# 213.38080697274592
# length of actions is  308
# -15.636087159497393
# length of actions is  252
# 215.07079493731277
# length of actions is  587
# 22.74684050409647
# length of actions is  236
# 235.02780070732967
# length of actions is  331
# Your final reward is : 134.12
# torch.from_numpy(rewards) looks like  torch.Size([1817])
# 219.98018711479898
# length of actions is  293
# 239.91437556280604
# length of actions is  414
# 211.76649452248998
# length of actions is  374
# 78.16658718824418
# length of actions is  1000
# 215.65442158880848
# length of actions is  368
# Your final reward is : 193.10
# torch.from_numpy(rewards) looks like  torch.Size([2952])
# 105.08745364550373
# length of actions is  1000
# 96.0458218541981
# length of actions is  1000
# 79.15858975614977
# length of actions is  1000
# 132.82473846640215
# length of actions is  1000
# 172.26913070445121
# length of actions is  457
# Your final reward is : 117.08
# torch.from_numpy(rewards) looks like  torch.Size([3358])
# 223.09168268744637
# length of actions is  298
# 217.32947233899836
# length of actions is  429
# 207.49139079824084
# length of actions is  443
# 278.5565906099157
# length of actions is  607
# 209.31381203219186
# length of actions is  930
# Your final reward is : 227.16
# torch.from_numpy(rewards) looks like  torch.Size([2867])
# 114.43001851611453
# length of actions is  1000
# 207.96969165995398
# length of actions is  486
# 224.0225470700333
# length of actions is  603
# 230.64756135255777
# length of actions is  321
# 240.4495984756998
# length of actions is  410
# Your final reward is : 203.50
# torch.from_numpy(rewards) looks like  torch.Size([1963])
# 223.7859516690045
# length of actions is  340
# 222.4086586148353
# length of actions is  534
# 204.70233420414067
# length of actions is  316
# 188.01778865913943
# length of actions is  392
# 235.75607418398772
# length of actions is  304
# Your final reward is : 214.93
# torch.from_numpy(rewards) looks like  torch.Size([2429])
# -13.936438167476695
# length of actions is  291
# 79.2043474917373
# length of actions is  1000
# 130.92072088873127
# length of actions is  1000
# 185.97037584664534
# length of actions is  557
# 201.85168183681094
# length of actions is  379
# Your final reward is : 116.80
# torch.from_numpy(rewards) looks like  torch.Size([2687])
# 218.83920845400775
# length of actions is  326
# 106.02575755581447
# length of actions is  1000
# 239.93722503408847
# length of actions is  422
# 251.1318379287978
# length of actions is  270
# 208.18976080965786
# length of actions is  391
# Your final reward is : 204.82
# torch.from_numpy(rewards) looks like  torch.Size([3366])
# 17.563281391673627
# length of actions is  294
# 182.11131542098542
# length of actions is  720
# 169.77126956604658
# length of actions is  560
# 255.35909325211853
# length of actions is  337
# 205.82121636330908
# length of actions is  590
# Your final reward is : 166.13
# torch.from_numpy(rewards) looks like  torch.Size([2579])
# 225.18073590281793
# length of actions is  345
# 195.77125703733716
# length of actions is  395
# 6.526481281611779
# length of actions is  1000
# 100.23999185478107
# length of actions is  1000
# 73.79913954602465
# length of actions is  1000
# Your final reward is : 120.30
# torch.from_numpy(rewards) looks like  torch.Size([3638])
# -1.6667050524426799
# length of actions is  287
# 202.17171525158292
# length of actions is  771
# 198.69302377070818
# length of actions is  502
# 31.038252442622145
# length of actions is  1000
# -21.184311419100236
# length of actions is  1000
# Your final reward is : 81.81
# torch.from_numpy(rewards) looks like  torch.Size([3142])
# -21.065157980088827
# length of actions is  1000
# 213.05772633544734
# length of actions is  642
# 36.141975410879276
# length of actions is  1000
# -25.26491096707438
# length of actions is  1000
# 17.203641155549025
# length of actions is  1000
# Your final reward is : 44.01
# torch.from_numpy(rewards) looks like  torch.Size([3975])
# 56.603374041967676
# length of actions is  1000
# 95.32903104720066
# length of actions is  1000
# 59.66139649726514
# length of actions is  1000
# 69.94076397534796
# length of actions is  1000
# -33.53769358792348
# length of actions is  1000
# Your final reward is : 49.60
# torch.from_numpy(rewards) looks like  torch.Size([3772])
# -27.891134869821855
# length of actions is  287
# 179.55045694597246
# length of actions is  577
# 168.57454283185177
# length of actions is  697
# 157.6089843395974
# length of actions is  785
# -44.8835379685828
# length of actions is  1000
# Your final reward is : 86.59
# torch.from_numpy(rewards) looks like  torch.Size([2867])
# -30.8992680819874
# length of actions is  285
# 236.56885723623265
# length of actions is  515
# 136.09380036900717
# length of actions is  759
# 188.27692715148436
# length of actions is  863
# 144.80713202020962
# length of actions is  698
# Your final reward is : 134.97
# torch.from_numpy(rewards) looks like  torch.Size([2263])
# 143.9290154438956
# length of actions is  751
# 176.72263922522055
# length of actions is  503
# 77.06099477223489
# length of actions is  1000
# 206.97005465535244
# length of actions is  569
# 217.7357936621366
# length of actions is  503
# Your final reward is : 164.48
# torch.from_numpy(rewards) looks like  torch.Size([3310])
# -0.8165799026566987
# length of actions is  277
# 124.45269532928268
# length of actions is  1000
# 231.21533439763977
# length of actions is  555
# 178.56616898769062
# length of actions is  632
# 229.78361976334915
# length of actions is  446
# Your final reward is : 152.64
# torch.from_numpy(rewards) looks like  torch.Size([2336])
# 123.41900005026167
# length of actions is  1000
# 250.71305905152622
# length of actions is  454
# 257.2708569574377
# length of actions is  991
# 258.5351381810681
# length of actions is  425
# 193.53620849819904
# length of actions is  407
# Your final reward is : 216.69
# torch.from_numpy(rewards) looks like  torch.Size([2331])
# 119.25901345296961
# length of actions is  1000
# 233.94887740619544
# length of actions is  542
# 146.86680449406256
# length of actions is  1000
# 221.48589916983298
# length of actions is  472
# 177.38121768965289
# length of actions is  599
# Your final reward is : 179.79
# torch.from_numpy(rewards) looks like  torch.Size([2551])
# 128.4977830516482
# length of actions is  1000
# 251.53709295298964
# length of actions is  471
# 249.41621272486654
# length of actions is  316
# 150.48786905811278
# length of actions is  1000
# 209.76957025714796
# length of actions is  501
# Your final reward is : 197.94
# torch.from_numpy(rewards) looks like  torch.Size([2548])
# -2.014063779309666
# length of actions is  279
# 136.26175704677277
# length of actions is  1000
# 184.63454200984867
# length of actions is  597
# 229.50385246270258
# length of actions is  432
# 186.56315418513657
# length of actions is  514
# Your final reward is : 146.99
# torch.from_numpy(rewards) looks like  torch.Size([2082])
# 201.9758784215182
# length of actions is  370
# 153.43430287581438
# length of actions is  804
# 216.57330849650265
# length of actions is  469
# 236.4064149572303
# length of actions is  461
# 208.63666459052428
# length of actions is  528
# Your final reward is : 203.41
# torch.from_numpy(rewards) looks like  torch.Size([1618])
# 10.359435318663188
# length of actions is  265
# 217.32429706255533
# length of actions is  501
# 42.08958053606531
# length of actions is  246
# 149.54472495753583
# length of actions is  1000
# 254.62646894994742
# length of actions is  425
# Your final reward is : 134.79
# torch.from_numpy(rewards) looks like  torch.Size([3105])
# 7.697785789323561
# length of actions is  261
# 38.18410235630357
# length of actions is  1000
# 82.32669139896907
# length of actions is  1000
# 146.53410140459798
# length of actions is  1000
# 133.86902312540713
# length of actions is  1000
# Your final reward is : 81.72
# torch.from_numpy(rewards) looks like  torch.Size([2346])
# 201.61932456302054
# length of actions is  790
# 141.62682508078763
# length of actions is  760
# 252.24969498578247
# length of actions is  324
# 262.38584013932586
# length of actions is  290
# 288.9223663473248
# length of actions is  344
# Your final reward is : 229.36
# torch.from_numpy(rewards) looks like  torch.Size([2293])
# 221.39674393354616
# length of actions is  355
# 232.47302475475726
# length of actions is  254
# 131.39540007304066
# length of actions is  1000
# 229.8229913887189
# length of actions is  271
# -39.34184587327519
# length of actions is  239
# Your final reward is : 155.15
# torch.from_numpy(rewards) looks like  torch.Size([3558])
# 207.7832289294408
# length of actions is  290
# 158.47473535526547
# length of actions is  1000
# 152.94259713843846
# length of actions is  1000
# 218.58022847770712
# length of actions is  215
# 155.44327952605238
# length of actions is  1000
# Your final reward is : 178.64
# torch.from_numpy(rewards) looks like  torch.Size([1188])
# 199.13845081384784
# length of actions is  298
# 227.8985031605842
# length of actions is  233
# 141.47201869516869
# length of actions is  694
# 216.08869508105954
# length of actions is  249
# 21.18666789115366
# length of actions is  198
# Your final reward is : 161.16
# torch.from_numpy(rewards) looks like  torch.Size([1649])
# 222.27351654177744
# length of actions is  244
# 237.19520603885735
# length of actions is  253
# 120.40367250144907
# length of actions is  1000
# 272.63856772260823
# length of actions is  214
# 249.73902313984763
# length of actions is  301
# Your final reward is : 220.45
# torch.from_numpy(rewards) looks like  torch.Size([1042])
# 228.8766527863081
# length of actions is  234
# 42.40766481505406
# length of actions is  183
# 4.193493026105813
# length of actions is  158
# 154.42145641861987
# length of actions is  656
# 281.26785806660365
# length of actions is  404
# Your final reward is : 142.23
# torch.from_numpy(rewards) looks like  torch.Size([1026])
# 221.66505466021798
# length of actions is  321
# 33.391937998759374
# length of actions is  187
# 206.0704558607016
# length of actions is  428
# 32.86263744428396
# length of actions is  172
# 239.98681317250742
# length of actions is  528
# Your final reward is : 146.80
# torch.from_numpy(rewards) looks like  torch.Size([1766])
# 216.76412993545998
# length of actions is  276
# 8.884807589169199
# length of actions is  205
# 254.79920015706452
# length of actions is  289
# 29.221709093164264
# length of actions is  213
# -174.56794770809705
# length of actions is  485
# Your final reward is : 67.02
# torch.from_numpy(rewards) looks like  torch.Size([1069])
# 221.66123259618212
# length of actions is  222
# 207.5864908131636
# length of actions is  219
# 237.06720657618777
# length of actions is  230
# 206.01936650309779
# length of actions is  227
# 149.67296876630627
# length of actions is  1000
# Your final reward is : 204.40
# torch.from_numpy(rewards) looks like  torch.Size([1210])
# -13.680365615288963
# length of actions is  190
# -18.847218358466947
# length of actions is  203
# 209.56123347817555
# length of actions is  199
# 227.88487262079252
# length of actions is  256
# 256.2899037243292
# length of actions is  214
# Your final reward is : 132.24
# torch.from_numpy(rewards) looks like  torch.Size([1500])
# 6.248366676558092
# length of actions is  244
# 252.0957176325571
# length of actions is  203
# 252.82737839965566
# length of actions is  207
# 137.5838859496428
# length of actions is  1000
# 259.066734959684
# length of actions is  262
# Your final reward is : 181.56
# torch.from_numpy(rewards) looks like  torch.Size([1106])
# 6.269947388443995
# length of actions is  246
# 265.48196343709435
# length of actions is  217
# 28.03178424698652
# length of actions is  206
# 100.37986800287943
# length of actions is  1000
# 229.6340495529518
# length of actions is  346
# Your final reward is : 125.96
# torch.from_numpy(rewards) looks like  torch.Size([1643])
# 9.308469490177288
# length of actions is  255
# 242.61891892006108
# length of actions is  226
# 253.63621163893927
# length of actions is  283
# 58.45256145834753
# length of actions is  167
# 235.73759754193765
# length of actions is  259
# Your final reward is : 159.95
# torch.from_numpy(rewards) looks like  torch.Size([1468])
# 12.679430548454604
# length of actions is  274
# 55.476139399884346
# length of actions is  148
# 4.757734107347865
# length of actions is  1000
# 5.211162730017307
# length of actions is  205
# -23.230385167902185
# length of actions is  181
# Your final reward is : 10.98
# torch.from_numpy(rewards) looks like  torch.Size([1217])
# 110.46430265687184
# length of actions is  833
# 57.0730932062591
# length of actions is  170
# 4.229154069343158
# length of actions is  1000
# -13.450363659989634
# length of actions is  179
# 274.1433019119031
# length of actions is  242
# Your final reward is : 86.49
# torch.from_numpy(rewards) looks like  torch.Size([2630])
# 151.47790504341995
# length of actions is  627
# 238.22846137667278
# length of actions is  362
# 242.99187358554997
# length of actions is  237
# 125.47060325793629
# length of actions is  970
# 218.71705260945424
# length of actions is  323
# Your final reward is : 195.38
# torch.from_numpy(rewards) looks like  torch.Size([3415])
# 150.8342470274878
# length of actions is  616
# 257.20516371774795
# length of actions is  247
# -3.9876683491908125
# length of actions is  86
# 18.56531213336956
# length of actions is  157
# 184.4671178338619
# length of actions is  483
# Your final reward is : 121.42
# torch.from_numpy(rewards) looks like  torch.Size([3713])
# 149.5576153933918
# length of actions is  610
# -122.1480849050368
# length of actions is  66
# -131.13357720593746
# length of actions is  80
# 38.64330303876979
# length of actions is  1000
# 157.65814583441295
# length of actions is  732
# Your final reward is : 18.52
# torch.from_numpy(rewards) looks like  torch.Size([1175])
# 155.7293814308548
# length of actions is  587
# 233.78523035841783
# length of actions is  250
# 125.48467238154679
# length of actions is  1000
# 136.68609795834604
# length of actions is  1000
# 152.03072247890898
# length of actions is  1000
# Your final reward is : 160.74
# torch.from_numpy(rewards) looks like  torch.Size([959])
# -37.13942770806425
# length of actions is  1000
# 227.97390948069437
# length of actions is  153
# -21.705841331357835
# length of actions is  1000
# 48.56585865899571
# length of actions is  1000
# 227.58174766623657
# length of actions is  217
# Your final reward is : 89.06
# torch.from_numpy(rewards) looks like  torch.Size([1826])
# 6.6857208649004605
# length of actions is  269
# 226.46637008786092
# length of actions is  246
# -23.278742231484827
# length of actions is  158
# 187.44766601321368
# length of actions is  481
# 197.853911518949
# length of actions is  268
# Your final reward is : 119.03
# torch.from_numpy(rewards) looks like  torch.Size([1965])
# -3.598215256652736
# length of actions is  174
# 181.90306079856342
# length of actions is  647
# 123.80310657764888
# length of actions is  1000
# 222.67604669806406
# length of actions is  233
# 234.46557074292278
# length of actions is  223
# Your final reward is : 151.85
# torch.from_numpy(rewards) looks like  torch.Size([2032])
# 84.70065657550468
# length of actions is  1000
# 17.176846818737772
# length of actions is  160
# 72.70900953422189
# length of actions is  1000
# 244.39136840547297
# length of actions is  238
# 129.35240573866284
# length of actions is  1000
# Your final reward is : 109.67
# torch.from_numpy(rewards) looks like  torch.Size([2347])
# 202.22731748390754
# length of actions is  326
# 63.774599021239055
# length of actions is  1000
# 44.75855436445508
# length of actions is  117
# -59.06793768698391
# length of actions is  208
# 233.76823981312543
# length of actions is  267
# Your final reward is : 97.09
# torch.from_numpy(rewards) looks like  torch.Size([1773])
# 88.62806364717662
# length of actions is  1000
# 226.46467068657384
# length of actions is  222
# 124.47310826894838
# length of actions is  1000
# -18.001231921870936
# length of actions is  1000
# 80.83992550073341
# length of actions is  1000
# Your final reward is : 100.48
# torch.from_numpy(rewards) looks like  torch.Size([2214])
# 176.6232162201705
# length of actions is  486
# 208.59862493404466
# length of actions is  224
# 109.72111112327234
# length of actions is  1000
# -11.340560146549265
# length of actions is  1000
# -24.523183148113816
# length of actions is  161
# Your final reward is : 91.82
# torch.from_numpy(rewards) looks like  torch.Size([3426])
# 87.52271863355263
# length of actions is  1000
# -15.587640542270279
# length of actions is  170
# -28.873369884759427
# length of actions is  171
# 223.06796713955907
# length of actions is  758
# -55.404631485967826
# length of actions is  197
# Your final reward is : 42.15
# torch.from_numpy(rewards) looks like  torch.Size([1347])
# 84.37033373396326
# length of actions is  1000
# 18.617433455921386
# length of actions is  164
# -15.585177984802868
# length of actions is  185
# -9.255684002069302
# length of actions is  146
# -47.30925849222638
# length of actions is  187
# Your final reward is : 6.17
# torch.from_numpy(rewards) looks like  torch.Size([1996])
# 45.232062807137936
# length of actions is  1000
# 37.96148046032704
# length of actions is  95
# 219.4690643832344
# length of actions is  270
# 107.08568577530042
# length of actions is  995
# 222.64866545865698
# length of actions is  176
# Your final reward is : 126.48
# torch.from_numpy(rewards) looks like  torch.Size([2373])
# 117.50352331957778
# length of actions is  832
# 15.401577907754145
# length of actions is  165
# -3.1422597892011415
# length of actions is  1000
# -43.759297146717415
# length of actions is  174
# 115.18318957918602
# length of actions is  1000
# Your final reward is : 40.24
# torch.from_numpy(rewards) looks like  torch.Size([2656])
# 169.45463075885334
# length of actions is  608
# 116.87432883338343
# length of actions is  1000
# -37.51106341382369
# length of actions is  101
# 189.2049139263903
# length of actions is  601
# 111.7587126084219
# length of actions is  939
# Your final reward is : 109.96
# torch.from_numpy(rewards) looks like  torch.Size([4250])
# 192.38840585074274
# length of actions is  399
# -16.25679733117097
# length of actions is  1000
# 111.8726272131244
# length of actions is  999
# 130.5757738870086
# length of actions is  1000
# 228.92349794193134
# length of actions is  260
# Your final reward is : 129.50
# torch.from_numpy(rewards) looks like  torch.Size([3973])
# 223.86080215305464
# length of actions is  319
# 9.474298520838502
# length of actions is  88
# -12.610444929889525
# length of actions is  99
# -113.12932872077245
# length of actions is  68
# 50.29505098910298
# length of actions is  1000
# Your final reward is : 31.58
# torch.from_numpy(rewards) looks like  torch.Size([1017])
# 61.42625043343656
# length of actions is  1000
# 216.8766938531482
# length of actions is  180
# 273.6741671055245
# length of actions is  199
# -3.009593844897026
# length of actions is  85
# 197.9617107325932
# length of actions is  744
# Your final reward is : 149.39
# torch.from_numpy(rewards) looks like  torch.Size([1188])
# 195.30790981885917
# length of actions is  787
# 274.1626641365086
# length of actions is  228
# 171.23907252705223
# length of actions is  410
# 212.346368228391
# length of actions is  413
# -9.958347595692018
# length of actions is  111
# Your final reward is : 168.62
# torch.from_numpy(rewards) looks like  torch.Size([1513])
# 161.83556018477128
# length of actions is  564
# 230.29289414945208
# length of actions is  168
# 179.177276160029
# length of actions is  522
# 193.67274566526288
# length of actions is  451
# 257.1158216368512
# length of actions is  339
# Your final reward is : 204.42
# torch.from_numpy(rewards) looks like  torch.Size([1033])
# 209.70495371853252
# length of actions is  326
# 174.34366909326553
# length of actions is  621
# 233.10602101293082
# length of actions is  177
# 135.47646939391714
# length of actions is  718
# 214.85944036713659
# length of actions is  253
# Your final reward is : 193.50
# torch.from_numpy(rewards) looks like  torch.Size([1700])
# 223.55950919472645
# length of actions is  288
# 226.83279579679873
# length of actions is  301
# 136.52592104082862
# length of actions is  1000
# 222.4937806234114
# length of actions is  190
# 22.694967552465386
# length of actions is  1000
# Your final reward is : 166.42
# torch.from_numpy(rewards) looks like  torch.Size([1963])
# 191.89094290281207
# length of actions is  509
# -50.51275940161658
# length of actions is  186
# -1.0390847960641594
# length of actions is  152
# 138.50889220266362
# length of actions is  1000
# 224.63764989111718
# length of actions is  262
# Your final reward is : 100.70
# torch.from_numpy(rewards) looks like  torch.Size([2704])
# 181.41286531205486
# length of actions is  761
# 262.89080761512776
# length of actions is  243
# 81.74030188048437
# length of actions is  1000
# 159.26233250453134
# length of actions is  1000
# 251.01871771994269
# length of actions is  289
# Your final reward is : 187.27
# torch.from_numpy(rewards) looks like  torch.Size([3560])
# 217.69831460247906
# length of actions is  269
# 30.28981298223198
# length of actions is  113
# 138.26977389734256
# length of actions is  1000
# 239.76702990044907
# length of actions is  408
# -44.30740272442942
# length of actions is  168
# Your final reward is : 116.34
# torch.from_numpy(rewards) looks like  torch.Size([1963])
# 196.50509475332728
# length of actions is  486
# 203.6003247004508
# length of actions is  342
# -23.38117594762997
# length of actions is  188
# -14.496582152290728
# length of actions is  154
# -25.19019169791386
# length of actions is  170
# Your final reward is : 67.41
# torch.from_numpy(rewards) looks like  torch.Size([2921])
# 213.9241125101882
# length of actions is  458
# 129.14321554972
# length of actions is  813
# -29.896332759223412
# length of actions is  186
# 217.71009369171045
# length of actions is  259
# -7.402045808457305
# length of actions is  1000
# Your final reward is : 104.70
# torch.from_numpy(rewards) looks like  torch.Size([2820])
# 225.38380771522296
# length of actions is  327
# 147.53319616933868
# length of actions is  820
# 70.29684671249592
# length of actions is  1000
# 29.603305539438026
# length of actions is  190
# 211.0746526539678
# length of actions is  470
# Your final reward is : 136.78
# torch.from_numpy(rewards) looks like  torch.Size([3591])
# 260.3888074923639
# length of actions is  266
# 258.01677984222385
# length of actions is  796
# 132.66890818766728
# length of actions is  975
# 196.78640356723366
# length of actions is  651
# -6.990167015335662
# length of actions is  1000
# Your final reward is : 168.17
# torch.from_numpy(rewards) looks like  torch.Size([2521])
# 146.28701348405767
# length of actions is  1000
# 4.466625558617665
# length of actions is  177
# 248.1804335071784
# length of actions is  271
# 149.74559083981555
# length of actions is  1000
# 131.16879560278744
# length of actions is  1000
# Your final reward is : 135.97
# torch.from_numpy(rewards) looks like  torch.Size([2601])
# -7.446318086211619
# length of actions is  1000
# -15.635779504113486
# length of actions is  165
# 20.69886849868479
# length of actions is  1000
# 147.9803751787538
# length of actions is  818
# 179.80822777737762
# length of actions is  536
# Your final reward is : 65.08
# torch.from_numpy(rewards) looks like  torch.Size([2525])
# 223.21249934939067
# length of actions is  297
# 244.46016243517988
# length of actions is  257
# 175.45325451825812
# length of actions is  674
# 179.85521140761537
# length of actions is  609
# -11.541256810955588
# length of actions is  224
# Your final reward is : 162.29
# torch.from_numpy(rewards) looks like  torch.Size([2695])
# -28.021247677316747
# length of actions is  1000
# 253.1249619947899
# length of actions is  406
# 114.68636229097041
# length of actions is  1000
# 121.00830148763782
# length of actions is  1000
# 41.6564718080599
# length of actions is  1000
# Your final reward is : 100.49
# torch.from_numpy(rewards) looks like  torch.Size([1964])
# 220.83198444595072
# length of actions is  312
# 211.8328575016759
# length of actions is  630
# 20.87315482795664
# length of actions is  187
# 285.6443995394168
# length of actions is  241
# 51.283209136304094
# length of actions is  190
# Your final reward is : 158.09
# torch.from_numpy(rewards) looks like  torch.Size([2622])
# 207.21674939908138
# length of actions is  387
# 19.081549915086484
# length of actions is  194
# 60.286251220817064
# length of actions is  210
# 28.930404789869442
# length of actions is  211
# -2.0981971994289665
# length of actions is  287
# Your final reward is : 62.68
# torch.from_numpy(rewards) looks like  torch.Size([3025])
# 236.416641256722
# length of actions is  334
# 262.8827528723707
# length of actions is  284
# 274.93352298698494
# length of actions is  516
# 262.9925534885831
# length of actions is  274
# 270.2766558874962
# length of actions is  278
# Your final reward is : 261.50
# Improve to score 261.50 at batch 149
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:129: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# 串流輸出內容已截斷至最後 5000 行。
# length of actions is  1000
# 235.9446376567163
# length of actions is  271
# Your final reward is : 188.63
# torch.from_numpy(rewards) looks like  torch.Size([3316])
# -9.700822921731287
# length of actions is  182
# 237.5123421120138
# length of actions is  208
# 2.1567176997208435
# length of actions is  184
# 236.75729792558957
# length of actions is  473
# 187.4993863912596
# length of actions is  580
# Your final reward is : 130.84
# torch.from_numpy(rewards) looks like  torch.Size([2474])
# ...
# 265.8817047023623
# length of actions is  229
# 256.24491431874753
# length of actions is  267
# 255.14922037824465
# length of actions is  255
# 34.223441146803935
# length of actions is  147
# Your final reward is : 168.39
# torch.from_numpy(rewards) looks like  torch.Size([1214])
# 34.764705929574234
# length of actions is  139
# 230.08176177701841
# length of actions is  228
# 29.411322114702045
# length of actions is  124
# 265.3478927848483
# length of actions is  260
# 50.70477141130519
# length of actions is  142
# Your final reward is : 122.06
# torch.from_numpy(rewards) looks like  torch.Size([744])
# 19.572287420491577
# length of actions is  133
# 43.131630349272996
# length of actions is  168
# 161.69154696717143
# length of actions is  1000
# 31.04059325376369
# length of actions is  126
# 35.28483758007101
# length of actions is  160
# Your final reward is : 58.14
# torch.from_numpy(rewards) looks like  torch.Size([1118])
# 21.844974506749168
# length of actions is  121
# 22.04454073076566
# length of actions is  115
# 232.13284336857663
# length of actions is  242
# 298.4229050715285
# length of actions is  198
# 28.15342292521575
# length of actions is  128
# Your final reward is : 120.52
# torch.from_numpy(rewards) looks like  torch.Size([1316])
# 20.25047592772357
# length of actions is  115
# 57.35528698365715
# length of actions is  136
# 273.49616680765797
# length of actions is  211
# 48.089107702942044
# length of actions is  169
# 269.32359105035124
# length of actions is  244
# Your final reward is : 133.70
# torch.from_numpy(rewards) looks like  torch.Size([1799])
# 19.39901061207395
# length of actions is  115
# 35.16232710382832
# length of actions is  135
# 53.473788453670096
# length of actions is  140
# -14.776370274385783
# length of actions is  139
# 41.59469802536651
# length of actions is  120
# Your final reward is : 26.97
# torch.from_numpy(rewards) looks like  torch.Size([877])
# 13.64814373927534
# length of actions is  113
# 268.05256111568843
# length of actions is  196
# 55.27758120745452
# length of actions is  104
# 50.17752227999898
# length of actions is  124
# 273.6888308973188
# length of actions is  219
# Your final reward is : 132.17
# torch.from_numpy(rewards) looks like  torch.Size([2081])
# 20.706077130205983
# length of actions is  111
# 25.797855220454323
# length of actions is  133
# 251.97634060818305
# length of actions is  271
# 237.36412503388456
# length of actions is  256
# 34.34334333528892
# length of actions is  135
# Your final reward is : 114.04
# torch.from_numpy(rewards) looks like  torch.Size([1963])
# 29.325282986047654
# length of actions is  118
# 42.852506307961875
# length of actions is  132
# 285.0047981961315
# length of actions is  189
# 138.31101932110323
# length of actions is  1000
# 300.27088923599683
# length of actions is  191
# Your final reward is : 159.15
# torch.from_numpy(rewards) looks like  torch.Size([1820])
# 23.20102129953557
# length of actions is  117
# 40.329210079545874
# length of actions is  130
# 136.07080414439693
# length of actions is  1000
# 155.69528621223245
# length of actions is  1000
# 57.25890100062162
# length of actions is  112
# Your final reward is : 82.51
# torch.from_numpy(rewards) looks like  torch.Size([986])
# 25.962797958081012
# length of actions is  114
# 9.478751134224368
# length of actions is  138
# 231.13890892071734
# length of actions is  230
# 265.7378003155537
# length of actions is  240
# 36.567747726527756
# length of actions is  147
# Your final reward is : 113.78
# torch.from_numpy(rewards) looks like  torch.Size([815])
# 25.796228824826045
# length of actions is  115
# 50.97125254633329
# length of actions is  135
# 170.43285099223536
# length of actions is  1000
# 127.52369170916413
# length of actions is  1000
# 260.0636372534852
# length of actions is  211
# Your final reward is : 126.96
# torch.from_numpy(rewards) looks like  torch.Size([1176])
# 24.46143079921923
# length of actions is  113
# 272.02639951600213
# length of actions is  199
# 243.39289564285866
# length of actions is  301
# 286.0260395792356
# length of actions is  212
# 262.0024035348539
# length of actions is  255
# Your final reward is : 217.58
# torch.from_numpy(rewards) looks like  torch.Size([756])
# 37.433227798689785
# length of actions is  118
# 46.4567089690228
# length of actions is  138
# 25.323894835773416
# length of actions is  102
# 275.2519463453727
# length of actions is  584
# 261.243423127033
# length of actions is  251
# Your final reward is : 129.14
# torch.from_numpy(rewards) looks like  torch.Size([1191])
# 31.93194934316375
# length of actions is  114
# 2.678474644667702
# length of actions is  144
# 158.51718718378385
# length of actions is  1000
# 137.6910444894789
# length of actions is  1000
# 3.821067738825633
# length of actions is  127
# Your final reward is : 66.93
# torch.from_numpy(rewards) looks like  torch.Size([1621])
# 49.60880615884824
# length of actions is  118
# 55.09294858231635
# length of actions is  143
# 45.51139627649289
# length of actions is  129
# -28.776487520468564
# length of actions is  115
# 0.8751651490891703
# length of actions is  125
# Your final reward is : 24.46
# torch.from_numpy(rewards) looks like  torch.Size([1592])
# 40.46298989695404
# length of actions is  116
# 48.34900714666682
# length of actions is  143
# 272.04597535688856
# length of actions is  199
# 270.05327792636155
# length of actions is  276
# 253.73130531949445
# length of actions is  195
# Your final reward is : 176.93
# torch.from_numpy(rewards) looks like  torch.Size([1233])
# 47.163693425188825
# length of actions is  120
# 232.24110630647272
# length of actions is  864
# 11.880366684457016
# length of actions is  131
# -5.881357505446445
# length of actions is  108
# 18.15769072934657
# length of actions is  110
# Your final reward is : 60.71
# torch.from_numpy(rewards) looks like  torch.Size([2688])
# 33.58488953168904
# length of actions is  120
# 253.87181242115187
# length of actions is  201
# 289.59234086963056
# length of actions is  182
# 0.5535979756631946
# length of actions is  105
# 255.27244655965254
# length of actions is  290
# Your final reward is : 166.58
# torch.from_numpy(rewards) looks like  torch.Size([1833])
# 27.405835280835362
# length of actions is  117
# 287.81970847663933
# length of actions is  228
# 245.61273066240028
# length of actions is  239
# 271.71624022666674
# length of actions is  268
# 46.748686820316294
# length of actions is  143
# Your final reward is : 175.86
# torch.from_numpy(rewards) looks like  torch.Size([853])
# 42.26070833005642
# length of actions is  116
# 35.14036352507301
# length of actions is  129
# 37.15247238443763
# length of actions is  130
# 269.7347624415436
# length of actions is  211
# 38.19607335109501
# length of actions is  117
# Your final reward is : 84.50
# torch.from_numpy(rewards) looks like  torch.Size([599])
# 32.472051230428775
# length of actions is  117
# 35.77820512578029
# length of actions is  129
# 34.91156000318003
# length of actions is  130
# 273.1714988780391
# length of actions is  233
# 54.817105731723984
# length of actions is  149
# Your final reward is : 86.23
# torch.from_numpy(rewards) looks like  torch.Size([720])
# 47.412221541377136
# length of actions is  116
# 25.615333500605672
# length of actions is  124
# 218.19565770389892
# length of actions is  283
# 17.606703704819367
# length of actions is  116
# 158.73581063079033
# length of actions is  1000
# Your final reward is : 93.51
# torch.from_numpy(rewards) looks like  torch.Size([969])
# 250.85582692751552
# length of actions is  213
# 254.51470354083077
# length of actions is  247
# 202.72248765791977
# length of actions is  446
# 167.904046013461
# length of actions is  1000
# 174.25301959141993
# length of actions is  1000
# Your final reward is : 210.05
# torch.from_numpy(rewards) looks like  torch.Size([759])
# 41.36051260158348
# length of actions is  123
# 238.80111816717746
# length of actions is  226
# -6.288934814339228
# length of actions is  105
# 26.63451815160697
# length of actions is  118
# 247.46347834559572
# length of actions is  230
# Your final reward is : 109.59
# torch.from_numpy(rewards) looks like  torch.Size([958])
# 20.635727811641146
# length of actions is  112
# 46.875876405815404
# length of actions is  135
# 236.73798404324836
# length of actions is  236
# 46.92898318396189
# length of actions is  130
# 44.75541207707377
# length of actions is  136
# Your final reward is : 79.19
# torch.from_numpy(rewards) looks like  torch.Size([742])
# 35.93732497025954
# length of actions is  120
# 110.38171438180095
# length of actions is  1000
# 255.85284613803896
# length of actions is  302
# 55.82928076951555
# length of actions is  147
# 258.1436450565178
# length of actions is  230
# Your final reward is : 143.23
# torch.from_numpy(rewards) looks like  torch.Size([1511])
# 38.1390200745806
# length of actions is  116
# 35.86903040182165
# length of actions is  147
# -9.621561607744894
# length of actions is  114
# 239.19249058091964
# length of actions is  160
# 39.9429215997998
# length of actions is  138
# Your final reward is : 68.70
# torch.from_numpy(rewards) looks like  torch.Size([810])
# 27.990603311688005
# length of actions is  119
# 270.608691937932
# length of actions is  216
# 247.01659308506657
# length of actions is  284
# 24.729793398798563
# length of actions is  87
# 269.58456586429804
# length of actions is  196
# Your final reward is : 167.99
# torch.from_numpy(rewards) looks like  torch.Size([886])
# 22.198579042330124
# length of actions is  115
# 32.3264395837227
# length of actions is  139
# 34.89315691548239
# length of actions is  132
# 277.528435648788
# length of actions is  193
# 232.2368998702695
# length of actions is  188
# Your final reward is : 119.84
# torch.from_numpy(rewards) looks like  torch.Size([864])
# 28.627350802697748
# length of actions is  118
# 37.32706074428725
# length of actions is  144
# 128.1537874676221
# length of actions is  1000
# 271.072414589801
# length of actions is  201
# 267.69332203159667
# length of actions is  187
# Your final reward is : 146.57
# torch.from_numpy(rewards) looks like  torch.Size([1581])
# 238.85042929244625
# length of actions is  234
# 23.465514442486366
# length of actions is  144
# 39.996613270097924
# length of actions is  132
# 264.4944730478669
# length of actions is  226
# 40.935152372392366
# length of actions is  144
# Your final reward is : 121.55
# torch.from_numpy(rewards) looks like  torch.Size([1450])
# 234.80693867237483
# length of actions is  250
# 253.8315341095988
# length of actions is  192
# 58.28225142550687
# length of actions is  128
# 112.6381566209717
# length of actions is  1000
# 280.30080152524357
# length of actions is  198
# Your final reward is : 187.97
# torch.from_numpy(rewards) looks like  torch.Size([1951])
# 234.59563593584951
# length of actions is  193
# 43.07667893688074
# length of actions is  141
# -154.36100915106437
# length of actions is  267
# -24.65300576008036
# length of actions is  143
# 36.69134279523678
# length of actions is  138
# Your final reward is : 27.07
# torch.from_numpy(rewards) looks like  torch.Size([1498])
# 236.21333838770758
# length of actions is  181
# -15.408780008473812
# length of actions is  111
# -4.078402223846055
# length of actions is  81
# 219.71029685478658
# length of actions is  172
# 45.49435449120628
# length of actions is  134
# Your final reward is : 96.39
# torch.from_numpy(rewards) looks like  torch.Size([1083])
# 234.017839836089
# length of actions is  189
# -18.502168101230765
# length of actions is  108
# 26.67174603686884
# length of actions is  144
# 14.574493022723516
# length of actions is  135
# 165.44953291398514
# length of actions is  1000
# Your final reward is : 84.44
# torch.from_numpy(rewards) looks like  torch.Size([1472])
# 236.57374198145436
# length of actions is  164
# 241.94242305978548
# length of actions is  244
# -2.0870631520154603
# length of actions is  127
# 32.672704314088065
# length of actions is  72
# 136.6276904303216
# length of actions is  1000
# Your final reward is : 129.15
# torch.from_numpy(rewards) looks like  torch.Size([790])
# 236.3302767340826
# length of actions is  234
# 28.636919558426882
# length of actions is  144
# 42.329974339364526
# length of actions is  134
# 236.86139458125666
# length of actions is  244
# 31.23331822237236
# length of actions is  136
# Your final reward is : 115.08
# torch.from_numpy(rewards) looks like  torch.Size([897])
# 235.22861611573708
# length of actions is  187
# -1.8386003703569145
# length of actions is  125
# 271.81841764853846
# length of actions is  210
# 254.9930138058793
# length of actions is  178
# -7.736131873702817
# length of actions is  133
# Your final reward is : 150.49
# torch.from_numpy(rewards) looks like  torch.Size([905])
# 249.2313913742289
# length of actions is  213
# 32.11393250906036
# length of actions is  159
# 41.298564306621586
# length of actions is  144
# 241.27124657929357
# length of actions is  233
# 28.973846462986387
# length of actions is  143
# Your final reward is : 118.58
# torch.from_numpy(rewards) looks like  torch.Size([1856])
# 242.56840005673862
# length of actions is  176
# 285.4984819915543
# length of actions is  232
# -24.986205364113246
# length of actions is  139
# 23.084686747928316
# length of actions is  138
# 39.396750421107754
# length of actions is  143
# Your final reward is : 113.11
# torch.from_numpy(rewards) looks like  torch.Size([1039])
# 247.04228081392392
# length of actions is  198
# 260.5092565730681
# length of actions is  224
# -32.315529118640825
# length of actions is  120
# 22.78746301361454
# length of actions is  139
# 244.2573117620285
# length of actions is  258
# Your final reward is : 148.46
# torch.from_numpy(rewards) looks like  torch.Size([1783])
# 26.372880128466107
# length of actions is  123
# 212.18835190401535
# length of actions is  391
# 21.160104084082604
# length of actions is  146
# 226.23967249162325
# length of actions is  278
# 237.76717035358465
# length of actions is  322
# Your final reward is : 144.75
# torch.from_numpy(rewards) looks like  torch.Size([691])
# 242.86445674153998
# length of actions is  220
# 149.75483034854705
# length of actions is  1000
# 28.046638565093673
# length of actions is  148
# 222.67906709673503
# length of actions is  343
# 253.96234807627178
# length of actions is  696
# Your final reward is : 179.46
# torch.from_numpy(rewards) looks like  torch.Size([1361])
# 253.464552726073
# length of actions is  202
# 281.9851980593937
# length of actions is  215
# 146.11744586857225
# length of actions is  752
# 61.997007216504954
# length of actions is  145
# 17.568667309355035
# length of actions is  106
# Your final reward is : 152.23
# torch.from_numpy(rewards) looks like  torch.Size([1178])
# 243.24434736716387
# length of actions is  175
# 199.0025617961723
# length of actions is  416
# 31.662497632552686
# length of actions is  137
# -56.203727401638595
# length of actions is  129
# 202.11130654813238
# length of actions is  362
# Your final reward is : 123.96
# torch.from_numpy(rewards) looks like  torch.Size([1680])
# 20.74000057784953
# length of actions is  120
# 253.42430632595958
# length of actions is  219
# 23.577449086599813
# length of actions is  139
# 29.035162536968215
# length of actions is  146
# 257.4901548167767
# length of actions is  231
# Your final reward is : 116.85
# torch.from_numpy(rewards) looks like  torch.Size([1443])
# 19.922750001284825
# length of actions is  129
# 68.62117057141512
# length of actions is  154
# 19.1633261645719
# length of actions is  138
# 7.87667297652321
# length of actions is  137
# -10.961725624328807
# length of actions is  122
# Your final reward is : 20.92
# torch.from_numpy(rewards) looks like  torch.Size([1556])
# 16.737907722519694
# length of actions is  124
# 45.124942793100814
# length of actions is  158
# 25.976721560087853
# length of actions is  149
# 229.41071450634473
# length of actions is  341
# 33.67743036354463
# length of actions is  150
# Your final reward is : 70.19
# torch.from_numpy(rewards) looks like  torch.Size([922])
# 27.554043595809844
# length of actions is  127
# -15.023724617486579
# length of actions is  160
# 43.85244890017432
# length of actions is  116
# 234.44922509687981
# length of actions is  239
# -2.0302953623167213
# length of actions is  147
# Your final reward is : 57.76
# torch.from_numpy(rewards) looks like  torch.Size([1348])
# 21.17190287292756
# length of actions is  134
# -18.08609770993108
# length of actions is  133
# 190.63568872547637
# length of actions is  474
# -5.034904609765746
# length of actions is  178
# 275.6305634003526
# length of actions is  194
# Your final reward is : 92.86
# torch.from_numpy(rewards) looks like  torch.Size([1026])
# 16.235205455161193
# length of actions is  127
# -34.64641749478051
# length of actions is  143
# 282.12577253900713
# length of actions is  225
# -3.533109384763165
# length of actions is  110
# 24.400911900996448
# length of actions is  138
# Your final reward is : 56.92

# %% [markdown]
# ### Training Result
# During the training process, we recorded `avg_total_reward`, which represents the average total reward of episodes before updating the policy network.
#
# Theoretically, if the agent becomes better, the `avg_total_reward` will increase.
# The visualization of the training process is shown below:

# %%
# final score
plt.plot(avg_total_rewards)
plt.title("Total Rewards")
plt.show()

# %% [markdown]
# In addition, `avg_final_reward` represents average final rewards of episodes. To be specific, final rewards is the last reward received in one episode, indicating whether the craft lands successfully or not.

# %%
# to see if craft lands on surface successfully
plt.plot(avg_final_rewards)
plt.title("Final Rewards")
plt.show()

# %%
best_batch
# Out:
# 493

# %%
from google.colab import files
files.download(PATH)

# %% [markdown]
# # Server
# The code below simulate the environment on the judge server. Can be used for testing.

# %%
PATH = "Action_List_test" + str(best_batch) + ".npy"
action_list = np.load(PATH,allow_pickle=True) 
seed = 543 
fix(env, seed)

#agent.network.eval()  

test_total_reward = []
for actions in action_list:
    state = env.reset()
    img = plt.imshow(env.render(mode='rgb_array'))

    total_reward = 0

    done = False
    # while not done:
    done_count = 0
    for action in actions:
        # action, _ = agent1.sample(state)
        state, reward, done, _ = env.step(action)
        done_count += 1
        total_reward += reward
        if done:
            break
    #   img.set_data(env.render(mode='rgb_array'))
    #   display.display(plt.gcf())
    #   display.clear_output(wait=True)
    print(f"Your reward is : %.2f"%total_reward)
    test_total_reward.append(total_reward)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/__init__.py:422: UserWarning: torch.set_deterministic is deprecated and will be removed in a future release. Please use torch.use_deterministic_algorithms instead
#   "torch.set_deterministic is deprecated and will be removed in a future "
# Your reward is : 274.03
# Your reward is : 263.68
# Your reward is : 319.70
# Your reward is : 320.44
# Your reward is : 299.28

# %% [markdown]
# # Your score

# %%
print(f"Your final mean reward is : %.2f"%np.mean(test_total_reward))
# Out:
# Your final mean reward is : 295.43

# %% [markdown]
# ## Reference
#
# Below are some useful tips for you to get high score.
#
# - [DRL Lecture 1: Policy Gradient (Review)](https://youtu.be/z95ZYgPgXOY)
# - [ML Lecture 23-3: Reinforcement Learning (including Q-learning) start at 30:00](https://youtu.be/2-JNBzCq77c?t=1800)
# - [Lecture 7: Policy Gradient, David Silver](http://www0.cs.ucl.ac.uk/staff/d.silver/web/Teaching_files/pg.pdf)
